# %%
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torchvision
from torchvision import models,transforms
from torch.utils.data import DataLoader,Dataset
from torchvision.datasets import ImageFolder
import matplotlib.pyplot as plt
import cv2
from PIL import Image
import os
import shutil
import torch.optim as optim

import os
for dirname, _, filenames in os.walk('C:/Users/elika/Senior Design'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:/Users/elika/Senior Design\test1.ipynb
# C:/Users/elika/Senior Design\ChemTreat Image Analysis\Beginning_Image_Processing.ipynb
# C:/Users/elika/Senior Design\ChemTreat Image Analysis\Camera
# C:/Users/elika/Senior Design\ChemTreat Image Analysis\CNN_test.ipynb
# C:/Users/elika/Senior Design\ChemTreat Image Analysis\Initial Testing.ipynb
# C:/Users/elika/Senior Design\ChemTreat Image Analysis\README.md
# C:/Users/elika/Senior Design\ChemTreat Image Analysis\Video_Saving.ipynb
# C:/Users/elika/Senior Design\ChemTreat Image Analysis\.git\COMMIT_EDITMSG
# C:/Users/elika/Senior Design\ChemTreat Image Analysis\.git\config
# C:/Users/elika/Senior Design\ChemTreat Image Analysis\.git\description
# C:/Users/elika/Senior Design\ChemTreat Image Analysis\.git\FETCH_HEAD
# C:/Users/elika/Senior Design\ChemTreat Image Analysis\.git\HEAD
# C:/Users/elika/Senior Design\ChemTreat Image Analysis\.git\index
# C:/Users/elika/Senior Design\ChemTreat Image Analysis\.git\ORIG_HEAD
# ...

# %%
data = "../Data/Concrete/"
file = data+'Negative/00004.jpg'
print(file)
# Out:
# ../Data/Concrete/Negative/00004.jpg

# %%
image = cv2.imread(file)
plt.imshow(image)
plt.title('Negative')
# Out:
# Text(0.5, 1.0, 'Negative')

# %%
image = cv2.imread("../Data/Concrete/Positive/00004.jpg")
plt.imshow(image)
plt.title('Positive')
# Out:
# Text(0.5, 1.0, 'Positive')

# %%
print(os.getcwd())

if not os.path.exists("./working"):
    os.mkdir("./working")


os.chdir("./working")
print(os.getcwd())
os.makedirs('train/Positive', exist_ok=True)
os.makedirs('train/Negative', exist_ok=True)
os.makedirs('test/Positive', exist_ok=True)
os.makedirs('test/Negative', exist_ok=True)
os.makedirs('valid/Positive', exist_ok=True)
os.makedirs('valid/Negative', exist_ok=True)
# Out:
# C:\Users\elika\AppData\Local\Temp\ipykernel_33552\working\working\working\working\working\working\working\working\working\working
# C:\Users\elika\AppData\Local\Temp\ipykernel_33552\working\working\working\working\working\working\working\working\working\working\working

# %%
os.chdir('.working')

#Negative
for i, file_name in enumerate(os.listdir('.../Data/Concrete/Negative')):
    if i < 1000:
        src = os.path.join('.../Data/Concrete/Negative', file_name)
        dest = os.path.join('./train/Negative', file_name)
        shutil.copy(src,dest)
    elif i > 1000 and i < 1500 and file_name.endswith('.jpg'):
        dest = os.path.join('./valid/Negative', file_name)
        src = os.path.join('.../Data/Concrete/Negative', file_name)
        shutil.copy(src,dest)
    #else:
    #    shutil.copy('.../Data/Concrete/Negative/'+file_name, './valid/Negative')
