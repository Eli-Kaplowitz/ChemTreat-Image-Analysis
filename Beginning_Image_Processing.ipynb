# %%
#pip install pillow
from PIL import Image
import numpy as np

#img = Image.open("image2.png")
img = Image.open("../Data/Settling_Photos_VCU/Settling_Photos_VCU/Settling 1_3.jpg")

print(type(img))
print(img.format)

img1 = np.asarray(img)
print(type(img1))
#Print the numpy array as an array
print(img1)
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# <class 'numpy.ndarray'>
# [[[ 88  85  78]
#   [ 88  85  78]
#   [ 88  85  78]
#   ...
#   [ 68  70  69]
#   [ 68  70  69]
#   [ 68  70  69]]
#
#  [[ 88  85  78]
#   [ 88  85  78]
#   [ 88  85  78]
#   ...
#   [ 68  70  69]
#   [ 68  70  69]
#   [ 68  70  69]]
#
#  [[ 89  86  79]
#   [ 89  86  79]
#   [ 89  86  79]
#   ...
#   [ 68  70  69]
#   [ 68  70  69]
#   [ 68  70  69]]
#
#  ...
#
#  [[147 146 141]
#   [147 146 141]
#   [147 146 141]
#   ...
#   [164 165 159]
#   [164 165 159]
#   [164 165 159]]
#
#  [[147 146 141]
#   [147 146 141]
#   [147 146 141]
#   ...
#   [163 164 158]
#   [163 164 158]
#   [163 164 158]]
#
#  [[147 146 141]
#   [147 146 141]
#   [147 146 141]
#   ...
#   [163 164 158]
#   [163 164 158]
#   [163 164 158]]]

# %%
###########################################
##directly import image file as a np array
#matplotlib
#pyplot

# pip install matplotlib

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

img = mpimg.imread("../Data/Settling_Photos_VCU/Settling_Photos_VCU/Settling 1_3.jpg")
print(type(img))
print(img.shape)
#show the image

plt.imshow(img)
plt.colorbar()
# Out:
# <class 'numpy.ndarray'>
# (799, 603, 3)

# %%
#another way to import?
#pip install skikit-image

from skimage import io
import matplotlib.pyplot as plt

image = io.imread("image2.png")
print(type(image))
plt.imshow(image)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# <class 'numpy.ndarray'>

# %%
#another way to import? converting to floating point
#pip install skikit-image

from skimage import io, img_as_float, img_as_ubyte
import matplotlib.pyplot as plt

image = io.imread("../Data/Settling_Photos_VCU/Settling_Photos_VCU/Settling 1_3.jpg")
image_float = img_as_float(image)
#print(image_float)
plt.imshow(image_float*2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#openCV
# library of programming functions aimed at computer vision, good for images or
# videos. Has all the tools for object recognition

#pip install opencv-python

import cv2
from matplotlib import pyplot as plt

img = cv2.imread("../Data/Settling_Photos_VCU/Settling_Photos_VCU/Settling 1_3.jpg")
#add , #) to end of "image2.png" to change color
plt.imshow(img)
#colors are changed becaue openCV uses BGR and Matplotlib uses RGB

# %%
#openCV
# library of programming functions aimed at computer vision, good for images or
# videos. Has all the tools for object recognition

#pip install opencv-python

import cv2
from matplotlib import pyplot as plt

grey_img = cv2.imread("../Data/Settling_Photos_VCU/Settling_Photos_VCU/Settling 1_3.jpg", 0)
cv2.imshow("Grey Image", grey_img)

cv2.waitKey(0)
cv2.destroyAllWindows()
#note that cv2.imshow wont work in google colab
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 11
#       8 from matplotlib import pyplot as plt
#      10 grey_img = cv2.imread("../Data/Settling_Photos_VCU/Settling_Photos_VCU/Settling 1_3.jpg", 0)
# ---> 11 cv2.imshow("Grey Image", grey_img)
#      13 cv2.waitKey(0)
#      14 cv2.destroyAllWindows()
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1301: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
#automating image processsing task, this wont run right now unless filled in
#with file information and run outside of colab
import cv2
import glob

path = "../Data/Settling_Photos_VCU/Settling_Photos_VCU"
for file in glab.glab(path):
  print(file)
  #this will list files in a folder
  a = cv2.imread(file)
  print(a)

  c = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
  cv2.imshow("Color Image", c)
  cv2.waitKey(0)
  cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       4 import glob
#       6 path = "../Data/Settling_Photos_VCU/Settling_Photos_VCU"
# ----> 7 for file in glab.glab(path):
#       8   print(file)
#       9   #this will list files in a folder
#
# NameError: name 'glab' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
